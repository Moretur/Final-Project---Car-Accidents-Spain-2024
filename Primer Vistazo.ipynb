# %%
import pandas as pd
import numpy as np

# %%
acc_animales = pd.read_csv("ACC_ANIMALES_2024.csv")
accidentes_2024 = pd.read_csv("TABLA_ACCIDENTES_24.csv")
dic_animales = pd.read_csv("Diccionario_Tabla_Acc_Animales - INDICADORES.csv")

acc_animales.head()
# Out:
#          ID_NUM  IND_ACCDA  IND_ACCIV  TOTAL_MU30DF  TOTAL_HG30DF  \
# 0  202402235890          1          0             0             0
# 1  202402235891          1          0             0             0
# 2  202402235892          1          0             0             0
# 3  202402235893          1          0             0             0
# 4  202402235894          1          0             0             0
#
#    TOTAL_HL30DF FECHA_ACCIDENTE HORA_ACCIDENTE  MES_1F  ANYO  CCAA_1F  \
# 0             0       22/1/2024           1:50       1  2024        7
# 1             0        6/4/2024          23:30       4  2024        7
# 2             0       15/5/2024          21:45       5  2024        7
# 3             0        6/1/2024          20:30       1  2024        7
# 4             0        8/1/2024          14:15       1  2024        7
#
#    PROVINCIA_1F  COD_MUNICIPIO CARRETERA      KM  SENTIDO_1F  TIPO_VIA_3F  \
# ...

# %%
accidentes_2024
# Out:
#         ID_ACCIDENTE  ANYO  MES  DIA_SEMANA  HORA  COD_PROVINCIA  \
# 0                  1  2024    1           3    22              1
# 1                  2  2024    1           6    23              1
# 2                  3  2024    1           7     1              1
# 3                  4  2024    1           7     8              1
# 4                  5  2024    1           4    17              1
# ...              ...   ...  ...         ...   ...            ...
# 101991        101992  2024   10           1    14             51
# 101992        101993  2024   11           6    10             51
# 101993        101994  2024   12           5     8             51
# 101994        101995  2024   12           2    18             51
# 101995        101996  2024    3           5    18             52
#
#         COD_MUNICIPIO  ISLA  ZONA  ZONA_AGRUPADA  ... PRIORI_OTRA  \
# 0                   0   NaN     1              1  ...         999
# ...

# %%
accidentes_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101996 entries, 0 to 101995
# Data columns (total 73 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID_ACCIDENTE              101996 non-null  int64
#  1   ANYO                      101996 non-null  int64
#  2   MES                       101996 non-null  int64
#  3   DIA_SEMANA                101996 non-null  int64
#  4   HORA                      101996 non-null  int64
#  5   COD_PROVINCIA             101996 non-null  int64
#  6   COD_MUNICIPIO             101996 non-null  int64
#  7   ISLA                      4444 non-null    float64
#  8   ZONA                      101996 non-null  int64
#  9   ZONA_AGRUPADA             101996 non-null  int64
#  10  CARRETERA                 101996 non-null  object
#  11  KM                        38814 non-null   object
#  12  SENTIDO_1F                101996 non-null  int64
# ...

# %%
acc_animales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36087 entries, 0 to 36086
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_NUM              36087 non-null  int64
#  1   IND_ACCDA           36087 non-null  int64
#  2   IND_ACCIV           36087 non-null  int64
#  3   TOTAL_MU30DF        36087 non-null  int64
#  4   TOTAL_HG30DF        36087 non-null  int64
#  5   TOTAL_HL30DF        36087 non-null  int64
#  6   FECHA_ACCIDENTE     36087 non-null  object
#  7   HORA_ACCIDENTE      36087 non-null  object
#  8   MES_1F              36087 non-null  int64
#  9   ANYO                36087 non-null  int64
#  10  CCAA_1F             36087 non-null  int64
#  11  PROVINCIA_1F        36087 non-null  int64
#  12  COD_MUNICIPIO       36087 non-null  int64
#  13  CARRETERA           36087 non-null  object
#  14  KM                  36087 non-null  object
# ...

# %%
accidentes_2024.columns
# Out:
# Index(['ID_ACCIDENTE', 'ANYO', 'MES', 'DIA_SEMANA', 'HORA', 'COD_PROVINCIA',
#        'COD_MUNICIPIO', 'ISLA', 'ZONA', 'ZONA_AGRUPADA', 'CARRETERA', 'KM',
#        'SENTIDO_1F', 'TITULARIDAD_VIA', 'TIPO_VIA', 'TIPO_ACCIDENTE',
#        'TOTAL_MU24H', 'TOTAL_HG24H', 'TOTAL_HL24H', 'TOTAL_VICTIMAS_24H',
#        'TOTAL_MU30DF', 'TOTAL_HG30DF', 'TOTAL_HL30DF', 'TOTAL_VICTIMAS_30DF',
#        'TOTAL_VEHICULOS', 'TOT_PEAT_MU24H', 'TOT_BICI_MU24H',
#        'TOT_CICLO_MU24H', 'TOT_MOTO_MU24H', 'TOT_TUR_MU24H', 'TOT_FURG_MU24H',
#        'TOT_CAM_MENOS3500_MU24H', 'TOT_CAM_MAS3500_MU24H', 'TOT_BUS_MU24H',
#        'TOT_OTRO_MU24H', 'TOT_SINESPECIF_MU24H', 'TOT_PEAT_MU30DF',
#        'TOT_BICI_MU30DF', 'TOT_CICLO_MU30DF', 'TOT_MOTO_MU30DF',
#        'TOT_TUR_MU30DF', 'TOT_FURG_MU30DF', 'TOT_CAM_MENOS3500_MU30DF',
#        'TOT_CAM_MAS3500_MU30DF', 'TOT_BUS_MU30DF', 'TOT_VMP_MU30DF',
#        'TOT_OTRO_MU30DF', 'TOT_SINESPECIF_MU30DF', 'NUDO', 'NUDO_INFO',
# ...

# %%
accidentes_2024 = accidentes_2024[['ID_ACCIDENTE',"ANYO","MES","DIA_SEMANA","HORA",
    "COD_PROVINCIA","COD_MUNICIPIO","ZONA","ZONA_AGRUPADA",
    "CARRETERA", "KM",
    "TIPO_VIA", "TITULARIDAD_VIA",
    "TIPO_ACCIDENTE",
    "CONDICION_ILUMINACION", "CONDICION_METEO", "CONDICION_NIEBLA",
    "CONDICION_VIENTO", "VISIB_RESTRINGIDA_POR",
    "CONDICION_FIRME", "TRAZADO_PLANTA",
    "TOTAL_MU30DF", "TOTAL_HG30DF", "TOTAL_HL30DF", "TOTAL_VICTIMAS_30DF"]]

# %%
acc_animales.columns
# Out:
# Index(['ID_NUM', 'IND_ACCDA', 'IND_ACCIV', 'TOTAL_MU30DF', 'TOTAL_HG30DF',
#        'TOTAL_HL30DF', 'FECHA_ACCIDENTE', 'HORA_ACCIDENTE', 'MES_1F', 'ANYO',
#        'CCAA_1F', 'PROVINCIA_1F', 'COD_MUNICIPIO', 'CARRETERA', 'KM',
#        'SENTIDO_1F', 'TIPO_VIA_3F', 'TITULARIDAD_VIA_2F', 'TIPO_ANIMAL_1F',
#        'TIPO_ANIMAL_2F'],
#       dtype='object')

# %%
acc_animales = acc_animales[[ 
    'ID_NUM',
    'ANYO',
    'MES_1F',
    'FECHA_ACCIDENTE',
    'HORA_ACCIDENTE',
    'CCAA_1F',
    'PROVINCIA_1F',
    'COD_MUNICIPIO',
    'CARRETERA',
    'KM',
    'SENTIDO_1F',
    'TIPO_VIA_3F',
    'TITULARIDAD_VIA_2F',
    'TOTAL_MU30DF',
    'TOTAL_HG30DF',
    'TOTAL_HL30DF',
    'TIPO_ANIMAL_1F',
    'TIPO_ANIMAL_2F']]
